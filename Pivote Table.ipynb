# %% [markdown]
# TASK 2

# %% [markdown]
# Pivote Table

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
print(os.listdir())
# Out:
# ['Data analytics Task PDF.pdf', 'Data Cleaning.ipynb', 'data.csv', 'Employee Sample Data.xlsx', 'Iris.csv', 'Pivote Table.ipynb', 'Remove Duplication.ipynb']

# %%
df = pd.read_csv("data.csv", encoding= 'unicode_escape')

# %% [markdown]
# BEFORE APPLYING PIVOTE TABLES TO SUMMARIZE DATA

# %%
df
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age   Hire Date Annual Salary  \
# 0    Research & Development  Female      Black   55    4/8/2016     $141,604
# ...

# %% [markdown]
# AFTER APPLYING PIVOTE TABLES TO SUMMARIZE DATA

# %%
df.pivot_table(index = "Department", columns = "Bonus %")
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_15756\2597716686.py:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   df.pivot_table(index = "Department", columns = "Bonus %")
#                        Age                                                     \
# Bonus %                0%        10%        11%    12%        13%        14%
# Department
# Accounting       44.275000  42.500000        NaN  51.75  62.000000  39.000000
# Engineering      44.952830  60.500000  41.750000  53.75  45.666667  56.750000
# Finance          44.369565  57.500000  43.166667  45.40  52.666667  37.000000
# Human Resources  44.269231  32.666667  38.250000  45.00  40.400000  47.333333
# IT               44.693252  45.750000  36.000000  42.00        NaN  44.666667
# Marketing        43.465116  49.750000  50.000000  33.20  64.500000  40.000000
# ...
